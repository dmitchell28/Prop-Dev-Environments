# %% [markdown]
# # BQuant Spotlight Webinar Series
#
# This project contains companion notebooks for the BQuant spotlight webinar video series.
#
# ## Latest Spotlight Webinar
# <br>
# <div style="background-color: #232323; padding: 10px 25px">
#
# ### Is there Value in Value?
# This spotlight webinar covers the following topics:
#
# - Use BQL to define custom types of value premium
# - Retrieve equity and corporate credit data in the same query
# - Aggregate and visualize data across multiple asset classes
#
# <a href="./Value.ipynb">Notebook</a>
#
# </div>
# <br>
#
# ## ESG Webinar Series
#
# <br>
#
# <div style="background-color: #232323; padding: 10px 25px">
#
#
# ### Seeing Green Spotlight Webinar: Part 1 <br> <span style="color:orange"> ESG Scoring App Workflows </span>
# This spotlight webinar covers the following topics:
#
# - Access the new ESG data available in BQL for your target universe
# - Use the BQuant app template to quickly build your own ESG scoring app
#
# [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20345789178) | <a href="https://blinks.bloomberg.com/screens/BQNT%20ESGX">Notebook</a>
#
#
# ### Seeing Green Spotlight Webinar: Part 2 <br> <span style="color:orange">  Integrating Your Research into ESG Scoring Models </span>
# This spotlight webinar covers the following topics:
#
# - Use Bloomberg's custom data editor (CDE) to upload your research
# - Combine your research and BQuant's ESG score in a single scoring app
#
# [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20347803285) | <a href="https://blinks.bloomberg.com/screens/BQNT%20ESGX">Notebook</a>
#
# ### Seeing Green Spotlight Webinar: Part 3 <br> <span style="color:orange"> Finding ESG Bonds </span>
# This spotlight webinar covers the following topics:
#
# - Create an interactive app with ESG scores for a bond universe
# - Identify companies that have issued green bonds
#
# [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20347803759) | <a href="./ESG bonds.ipynb">Notebook</a>
#
# ### Seeing Green Spotlight Webinar: Part 4 <br> <span style="color:orange"> Improving Your Portfolio's ESG Score </span>
# This spotlight webinar covers the following topics:
#
# - Visualize the largest detractors to your portfolio's ESG score
# - Construct scenarios to determine the ESG impact of specific companies
#
# [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20350499534) | <a href="./ESG Portfolio Analysis/ESG Portfolio Analysis.ipynb">Notebook</a>
#
# </div>
# <br>
#
#
# ## Past Spotlight Webinars
#
# - Intro to JupyterLab in BQuant: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20333968934) | <a href="./Intro to JupyterLab in BQuant.ipynb">Notebook</a>
# - Intro to BQuant: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20329737029) | <a href="./Intro to BQuant Webinar.ipynb">Notebook</a>
# - Turkish Lira Crisis: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20330281983) | <a href="./Turkish Lira Crisis Webinar.ipynb">Notebook</a>
# - Technical Analysis: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20331688234) | <a href="./Technical Analysis Webinar.ipynb">Notebook</a>
# - Analyzing ESG Disclosure: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20332857866) | <a href="./Analyzing ESG Disclosure.ipynb">Notebook</a>
# - High Yield Interest Coverage and OAS: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20332757057) | <a href="./High Yield Interest Coverage and OAS.ipynb">Notebook</a>
# - Factor Trends in Earnings Season: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20334183988) | <a href="./Factor Trends in Earnings Season/Factor Trends in Earnings Season.ipynb">Notebook</a>
# - Adjusting Equity Factor Weights Based on Economic Regime: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20334785689) | <a href="./Economic Regime Factor Weighting.ipynb">Notebook</a>
# - When Companies Fail: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20335533667) | <a href="./When Companies Fail.ipynb">Notebook</a>
# - A China Case Study on Market Breadth: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20336538940) | <a href="./A China Case Study on Market Breadth.ipynb">Notebook</a>
# - Consistent Dividend Growth: Screening for Quality Companies: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20337895929) |  <a href="./Consistent Dividend Growth.ipynb">Notebook</a>
# - Balancing Act: Financial Statement Impact of Operating Leases: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20343053783) | <a href="./Balancing Act.ipynb">Notebook</a>
# - Go with the Flow: Deciphering Markets Using Fund Flow Data: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20340627751) | <a href="./Go with the Flow.ipynb">Notebook</a>
# - US-China Trade War: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20350003904) | <a href="./US-China Trade War.ipynb">Notebook</a>
# - Level Up Your BQuant Applications: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20352864519) | <a href="./App Building Tutorial/tutorial.ipynb">Notebook</a>
# - Integrating Bloomberg RMS into BQuant: [Video](https://blinks.bloomberg.com/screens/PLYR%20VOD%20356685386) | <a href="./Integrating RMS into BQuant.ipynb">Notebook</a>
#
# New notebooks will be added to this project as new webinar videos are released. For more information about any of the topics covered in the webinars, contact your Bloomberg representative.
